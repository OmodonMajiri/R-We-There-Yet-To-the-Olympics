# %%
# import modules
import os
import pandas as pd

# %%
olympicData = pd.read_csv('olympic_data.csv')
olympicData.head()
# Out:
#    id  athlete_id                      name sex   age  height  weight  \
# 0   1           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 1   2          15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 2   3          15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 3   4          16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 4   5          17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0
#
#              team  noc        games  ...  season       sport  \
# 0  Denmark/Sweden  DEN  1900 Summer  ...  Summer  Tug-Of-War
# 1         Finland  FIN  1920 Summer  ...  Summer    Swimming
# 2         Finland  FIN  1920 Summer  ...  Summer    Swimming
# 3         Finland  FIN  2014 Winter  ...  Winter  Ice Hockey
# 4         Finland  FIN  1952 Summer  ...  Summer  Gymnastics
#
#                                     event      city   medal host_city_lat  \
# 0             Tug-Of-War Men's Tug-Of-War     Paris    Gold     48.853410
# ...

# %%
olympicData.to_html('tableData.html', index=False, classes=['table', 'table-striped', 'table-hover'])
